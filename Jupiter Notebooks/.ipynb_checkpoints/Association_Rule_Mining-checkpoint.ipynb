# %% [markdown]
# <a href="https://colab.research.google.com/github/DABallentine/knowledge_discovery_charlotte/blob/main/Jupiter%20Notebooks/Association_Rule_Mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Association Rule Mining
#
# This Notebook takes the merged service requests and creates association rules on the data

# %%
# Import necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
# !pip install apyori
from apyori import apriori
# %matplotlib inline
plt.style.use('ggplot')

# Function to read data from URL
def read_data_from_URL(url):
    df=pd.read_csv(url)
    return df
# Out:
# Requirement already satisfied: apyori in /opt/anaconda3/lib/python3.8/site-packages (1.1.2)

# %%
#import the association rule packages
from mlxtend.frequent_patterns import apriori, fpmax, fpgrowth, association_rules

# %%
# Read in the merged, preprocessed data
serv_req_url='https://bitbucket.org/nthammad-uncc/knowledge_discovery_charlotte/raw/main/data/merged_requests.zip'
requests = read_data_from_URL(serv_req_url)
requests.head()
# Out:
#    Unnamed: 0  OBJECTID             DEPARTMENT  REQUEST_NO  \
# 0           0         1   Solid Waste Services     6402056
# 1           1         2  Housing and NBHD Serv     6402064
# 2           2         3   Solid Waste Services     6402082
# 3           3         4   Solid Waste Services     6402103
# 4           4         6           Finance/City     6402112
#
#                 REQUEST_CAT              REQUEST_TYPE        RECEIVED_DATE  \
# 0      NON_RECYCLABLE ITEMS      NON_RECYCLABLE ITEMS  2016-11-07 14:00:00
# 1  UTILITY VERIFICATION LTR  UTILITY VERIFICATION LTR  2016-11-07 14:00:00
# 2      NON_RECYCLABLE ITEMS      NON_RECYCLABLE ITEMS  2016-11-07 14:00:00
# 3            MISSED SERVICE          MISSED RECYCLING  2016-11-07 14:00:00
# 4                       CWP               CWP REQUEST  2016-11-07 14:00:00
#
#    RECEIVED_MONTH  RECEIVED_YEAR  SEASON  ...  \
# 0              11           2016       4  ...
# 1              11           2016       4  ...
# 2              11           2016       4  ...
# 3              11           2016       4  ...
# 4              11           2016       4  ...
#
#   PERCENT HOUSEHOLD INCOME_Higher Income Households  \
# 0                                          0.210336
# 1                                          0.084375
# 2                                          0.037530
# 3                                          0.053345
# 4                                          0.050732
#
#    PERCENT HOUSEHOLD INCOME_Retired Householders  \
# 0                                       0.157483
# 1                                       0.129942
# 2                                       0.113167
# 3                                       0.128969
# 4                                       0.097692
#
#    INCOME AND BENEFITS_Median households income (dollars)  \
# 0                                       79300.428571
# 1                                       63391.250000
# 2                                       41973.411765
# 3                                       46401.066667
# 4                                       42745.529412
#
#    INCOME AND BENEFITS_Mean households income (dollars)  \
# 0                                      111885.642857
# 1                                       74852.450000
# 2                                       51723.764706
# 3                                       59119.666667
# 4                                       53659.352941
#
#    INCOME AND BENEFITS_Per capita Income  \
# 0                           47529.928571
# 1                           29914.900000
# 2                           19338.294118
# 3                           22976.800000
# 4                           23808.882353
#
#    INCOME AND BENEFITS_Median earnings for workers (dollars)  \
# 0                                       43332.642857
# 1                                       37226.300000
# 2                                       23576.882353
# 3                                       28399.600000
# 4                                       29559.117647
#
#    PERCENT INSURED_Population with health insurance  \
# 0                                          0.917971
# 1                                          0.869184
# 2                                          0.814082
# 3                                          0.834642
# 4                                          0.825033
#
#    PERCENT INSURED_Population without health insurance  \
# 0                                           0.082029
# 1                                           0.130816
# 2                                           0.185918
# 3                                           0.165358
# 4                                           0.174967
#
#   PERCENTAGE BELOW POVERTY LEVEL_All  HISTORIC_REDLINING
# 0                           7.135714                 NaN
# 1                           8.050000                 NaN
# 2                          25.811765                 NaN
# 3                          16.960000                 NaN
# 4                          20.682353                   Y
#
# [5 rows x 45 columns]

# %%
#list all column names
requests.columns.values
# Out:
# array(['Unnamed: 0', 'OBJECTID', 'DEPARTMENT', 'REQUEST_NO',
#        'REQUEST_CAT', 'REQUEST_TYPE', 'RECEIVED_DATE', 'RECEIVED_MONTH',
#        'RECEIVED_YEAR', 'SEASON', 'INTERNAL_FIELD_OBSERVATION',
#        'NEIGHBORHOOD_PROFILE_AREA', 'BLOCK_NO', 'ZIP_CODE', 'X_COORD',
#        'Y_COORD', 'LATITUDE', 'LONGITUDE', 'RECEIVED_DAY', 'TOTAL_CALLS',
#        'ADDRESS_ID', 'CRIME_SCORE', 'EMPLOYED_All',
#        'PERCENT EMPLOYED_In labor force',
#        'PERCENT EMPLOYED_Not in labor force',
#        'PERCENT EMPLOYED_Female Only', 'COMMUTING TO WORK_All',
#        'PERCENT COMMUTING TO WORK_By Car',
#        'PERCENT COMMUTING TO WORK_Public transportation',
#        'PERCENT COMMUTING TO WORK_Walk',
#        'PERCENT COMMUTING TO WORK_Other',
#        'PERCENT COMMUTING TO WORK_Worked at home',
#        'INCOME AND BENEFITS_Total households',
#        'PERCENT HOUSEHOLD INCOME_Lower Income Households',
#        'PERCENT HOUSEHOLD INCOME_Mid Income Households',
#        'PERCENT HOUSEHOLD INCOME_Higher Income Households',
#        'PERCENT HOUSEHOLD INCOME_Retired Householders',
#        'INCOME AND BENEFITS_Median households income (dollars)',
#        'INCOME AND BENEFITS_Mean households income (dollars)',
#        'INCOME AND BENEFITS_Per capita Income',
#        'INCOME AND BENEFITS_Median earnings for workers (dollars)',
#        'PERCENT INSURED_Population with health insurance',
#        'PERCENT INSURED_Population without health insurance',
#        'PERCENTAGE BELOW POVERTY LEVEL_All', 'HISTORIC_REDLINING'],
#       dtype=object)

# %%
#calculate the day of the week to make the request count per neighborhood profile area lesser
requests['RECEIVED_DAY_OF_WEEK'] = pd.to_datetime(requests['RECEIVED_DATE']).dt.day_name()
requests['RECEIVED_MONTH']=requests['RECEIVED_MONTH'].apply(lambda x:str(x))

# %%
#function to calculate if the income bracket is predominantly low, mid or high
def calculate_income_bracket(low,mid,high):
    if low>mid and low>high:
        return 'Low'
    elif mid>high:
        return 'Mid'
    else:
        return 'High'

# %%
requests['PREDOMINANT_INCOME_BRACKET']=requests[['PERCENT HOUSEHOLD INCOME_Lower Income Households','PERCENT HOUSEHOLD INCOME_Mid Income Households','PERCENT HOUSEHOLD INCOME_Higher Income Households']].apply(lambda x: calculate_income_bracket(*x),axis=1)

# %%
requests['PREDOMINANT_INCOME_BRACKET'].value_counts()
# Out:
# Mid     1491811
# Low       29346
# High       2904
# Name: PREDOMINANT_INCOME_BRACKET, dtype: int64

# %%
requests['CRIME_SCORE']=requests['CRIME_SCORE'].apply(lambda x: round(x,3))
requests['NEIGHBORHOOD_PROFILE_AREA']=requests['NEIGHBORHOOD_PROFILE_AREA'].apply(lambda x: str(int(x)))

# %%
max_crime_score=requests['CRIME_SCORE'].max()
requests['CRIME_INDEX']=requests['CRIME_SCORE'].apply(lambda x: 'Low' if (x/max_crime_score)<=0.33 else ('Mid' if (x/max_crime_score)<=0.66 else 'High'))

# %%
requests.head()
# Out:
#    Unnamed: 0  OBJECTID             DEPARTMENT  REQUEST_NO  \
# 0           0         1   Solid Waste Services     6402056
# 1           1         2  Housing and NBHD Serv     6402064
# 2           2         3   Solid Waste Services     6402082
# 3           3         4   Solid Waste Services     6402103
# 4           4         6           Finance/City     6402112
#
#                 REQUEST_CAT              REQUEST_TYPE        RECEIVED_DATE  \
# 0      NON_RECYCLABLE ITEMS      NON_RECYCLABLE ITEMS  2016-11-07 14:00:00
# 1  UTILITY VERIFICATION LTR  UTILITY VERIFICATION LTR  2016-11-07 14:00:00
# 2      NON_RECYCLABLE ITEMS      NON_RECYCLABLE ITEMS  2016-11-07 14:00:00
# 3            MISSED SERVICE          MISSED RECYCLING  2016-11-07 14:00:00
# 4                       CWP               CWP REQUEST  2016-11-07 14:00:00
#
#   RECEIVED_MONTH  RECEIVED_YEAR  SEASON  ...  \
# 0             11           2016       4  ...
# 1             11           2016       4  ...
# 2             11           2016       4  ...
# 3             11           2016       4  ...
# 4             11           2016       4  ...
#
#   INCOME AND BENEFITS_Mean households income (dollars)  \
# 0                                      111885.642857
# 1                                       74852.450000
# 2                                       51723.764706
# 3                                       59119.666667
# 4                                       53659.352941
#
#   INCOME AND BENEFITS_Per capita Income  \
# 0                          47529.928571
# 1                          29914.900000
# 2                          19338.294118
# 3                          22976.800000
# 4                          23808.882353
#
#    INCOME AND BENEFITS_Median earnings for workers (dollars)  \
# 0                                       43332.642857
# 1                                       37226.300000
# 2                                       23576.882353
# 3                                       28399.600000
# 4                                       29559.117647
#
#    PERCENT INSURED_Population with health insurance  \
# 0                                          0.917971
# 1                                          0.869184
# 2                                          0.814082
# 3                                          0.834642
# 4                                          0.825033
#
#    PERCENT INSURED_Population without health insurance  \
# 0                                           0.082029
# 1                                           0.130816
# 2                                           0.185918
# 3                                           0.165358
# 4                                           0.174967
#
#    PERCENTAGE BELOW POVERTY LEVEL_All  HISTORIC_REDLINING  \
# 0                            7.135714                 NaN
# 1                            8.050000                 NaN
# 2                           25.811765                 NaN
# 3                           16.960000                 NaN
# 4                           20.682353                   Y
#
#    RECEIVED_DAY_OF_WEEK PREDOMINANT_INCOME_BRACKET  CRIME_INDEX
# 0                Monday                        Mid          Low
# 1                Monday                        Mid          Low
# 2                Monday                        Mid          Low
# 3                Monday                        Mid          Low
# 4                Monday                        Mid          Low
#
# [5 rows x 48 columns]

# %% [markdown]
# ## Association rules between Request Categories and Neighborhood Profile Areas

# %%
requests['REQUEST_CAT'].value_counts()
# Out:
# NON_RECYCLABLE ITEMS         820199
# RECYCLABLE ITEMS             196945
# CART                         107771
# HNS HEALTH AND SANITATION     77723
# TRANSPORTATION                52467
# MISSED SERVICE                43400
# GARBAGE                       30604
# 311 DOCUMENT                  22379
# RECYCLING                     22200
# VIOLATIONS                    15821
# YARD WASTE                    15796
# TIRES                         13440
# WEATHER AND ENVIRONMENTAL     11641
# ZONING                        11410
# DEAD ANIMAL COLLECTION        10701
# ZONING/COMPLAINT/ INSPECT      9994
# COMPLAINT                      8486
# HNS HOUSING                    8161
# BULKY ITEM                     8045
# ZON GENERAL INFO  INQUIRY      7894
# CUSTOMER FEEDBACK              6835
# BLOCKAGE                       4462
# CLEANLINESS                    3447
# CWP                            2645
# DISABILITY ACT                 2525
# ADMINISTRATIVE ACTIONS         2326
# ESCALATION REQUEST             1791
# UTILITY VERIFICATION LTR       1441
# ANIMAL FOUND REPORT            1195
# FIELD OBSERVED PROBLEM          508
# STW CNTY WATER QUALITY          467
# SW ONLY-DOOR HANGER LEFT        370
# PARK & REC SVC REQUEST          296
# BOARDED UP STRUCTURE            225
# REQUEST FOR SPEAKER             104
# ADOPT-A PICKUP SWS              102
# CONTENT IMPROVEMENT PROG         99
# STW OTHER                        98
# DISABLED SERVICE                 48
# Name: REQUEST_CAT, dtype: int64

# %%
#create a column to combine month, year and neighborhood profile area:
requests['MERGE_INDEX']=requests['RECEIVED_MONTH'].astype('str')+'_'+requests['RECEIVED_YEAR'].astype('str')+'_'+requests['NEIGHBORHOOD_PROFILE_AREA'].astype('str')
requests['REQ_COUNT']=1

# %%
requests.head()
# Out:
#    Unnamed: 0  OBJECTID             DEPARTMENT  REQUEST_NO  \
# 0           0         1   Solid Waste Services     6402056
# 1           1         2  Housing and NBHD Serv     6402064
# 2           2         3   Solid Waste Services     6402082
# 3           3         4   Solid Waste Services     6402103
# 4           4         6           Finance/City     6402112
#
#                 REQUEST_CAT              REQUEST_TYPE        RECEIVED_DATE  \
# 0      NON_RECYCLABLE ITEMS      NON_RECYCLABLE ITEMS  2016-11-07 14:00:00
# 1  UTILITY VERIFICATION LTR  UTILITY VERIFICATION LTR  2016-11-07 14:00:00
# 2      NON_RECYCLABLE ITEMS      NON_RECYCLABLE ITEMS  2016-11-07 14:00:00
# 3            MISSED SERVICE          MISSED RECYCLING  2016-11-07 14:00:00
# 4                       CWP               CWP REQUEST  2016-11-07 14:00:00
#
#   RECEIVED_MONTH  RECEIVED_YEAR  SEASON  ...  \
# 0             11           2016       4  ...
# 1             11           2016       4  ...
# 2             11           2016       4  ...
# 3             11           2016       4  ...
# 4             11           2016       4  ...
#
#   INCOME AND BENEFITS_Median earnings for workers (dollars)  \
# 0                                       43332.642857
# 1                                       37226.300000
# 2                                       23576.882353
# 3                                       28399.600000
# 4                                       29559.117647
#
#   PERCENT INSURED_Population with health insurance  \
# 0                                         0.917971
# 1                                         0.869184
# 2                                         0.814082
# 3                                         0.834642
# 4                                         0.825033
#
#    PERCENT INSURED_Population without health insurance  \
# 0                                           0.082029
# 1                                           0.130816
# 2                                           0.185918
# 3                                           0.165358
# 4                                           0.174967
#
#    PERCENTAGE BELOW POVERTY LEVEL_All  HISTORIC_REDLINING  \
# 0                            7.135714                 NaN
# 1                            8.050000                 NaN
# 2                           25.811765                 NaN
# 3                           16.960000                 NaN
# 4                           20.682353                   Y
#
#    RECEIVED_DAY_OF_WEEK  PREDOMINANT_INCOME_BRACKET  CRIME_INDEX  MERGE_INDEX  \
# 0                Monday                         Mid          Low  11_2016_215
# 1                Monday                         Mid          Low  11_2016_265
# 2                Monday                         Mid          Low  11_2016_103
# 3                Monday                         Mid          Low  11_2016_158
# 4                Monday                         Mid          Low   11_2016_88
#
#    REQ_COUNT
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#
# [5 rows x 50 columns]

# %%
#create a matrix of merge index and category with the values as sum of requests(number of requests of 
# a particular category raised per month of a year for a particular neighborhood profile area) 
request_basket = (requests
          .groupby(['MERGE_INDEX','REQUEST_CAT'])['REQ_COUNT']
          .sum().unstack().reset_index().fillna(0)
          .set_index('MERGE_INDEX'))
request_basket.head(20)
# Out:
# REQUEST_CAT  311 DOCUMENT  ADMINISTRATIVE ACTIONS  ADOPT-A PICKUP SWS  \
# MERGE_INDEX
# 10_2016_10            3.0                     2.0                 0.0
# 10_2016_100           2.0                     0.0                 0.0
# 10_2016_101           0.0                     0.0                 0.0
# 10_2016_102           0.0                     0.0                 0.0
# 10_2016_103           1.0                     0.0                 0.0
# 10_2016_105           0.0                     1.0                 0.0
# 10_2016_106           0.0                     0.0                 0.0
# 10_2016_107           1.0                     0.0                 0.0
# 10_2016_108           0.0                     0.0                 0.0
# 10_2016_109           0.0                     0.0                 0.0
# 10_2016_11            2.0                     0.0                 0.0
# 10_2016_110           0.0                     0.0                 0.0
# 10_2016_111           0.0                     0.0                 0.0
# 10_2016_112           0.0                     0.0                 0.0
# 10_2016_113           3.0                     0.0                 0.0
# 10_2016_114           0.0                     1.0                 0.0
# 10_2016_115           0.0                     0.0                 0.0
# 10_2016_116           4.0                     1.0                 0.0
# 10_2016_117           3.0                     3.0                 0.0
# 10_2016_118           0.0                     0.0                 0.0
#
# REQUEST_CAT  ANIMAL FOUND REPORT  BLOCKAGE  BOARDED UP STRUCTURE  BULKY ITEM  \
# MERGE_INDEX
# 10_2016_10                   0.0       0.0                   0.0         2.0
# 10_2016_100                  0.0       0.0                   0.0         0.0
# 10_2016_101                  0.0       0.0                   0.0         0.0
# 10_2016_102                  0.0       0.0                   0.0         0.0
# 10_2016_103                  0.0       0.0                   0.0         0.0
# 10_2016_105                  0.0       0.0                   0.0         0.0
# 10_2016_106                  0.0       0.0                   0.0         0.0
# 10_2016_107                  0.0       0.0                   0.0         0.0
# 10_2016_108                  0.0       0.0                   0.0         0.0
# 10_2016_109                  0.0       0.0                   0.0         0.0
# 10_2016_11                   0.0       1.0                   0.0         0.0
# 10_2016_110                  0.0       0.0                   0.0         0.0
# 10_2016_111                  0.0       0.0                   0.0         0.0
# 10_2016_112                  0.0       0.0                   0.0         0.0
# 10_2016_113                  0.0       0.0                   0.0         1.0
# 10_2016_114                  0.0       0.0                   0.0         0.0
# 10_2016_115                  0.0       1.0                   0.0         0.0
# 10_2016_116                  0.0       1.0                   0.0         1.0
# 10_2016_117                  0.0       0.0                   0.0         1.0
# 10_2016_118                  0.0       0.0                   0.0         0.0
#
# REQUEST_CAT  CART  CLEANLINESS  COMPLAINT  ...  SW ONLY-DOOR HANGER LEFT  \
# MERGE_INDEX                                ...
# 10_2016_10   18.0          0.0        0.0  ...                       0.0
# 10_2016_100   4.0          0.0        1.0  ...                       0.0
# 10_2016_117                        1.0         0.0                        0.0
# 10_2016_118                        1.0         0.0                        0.0
#
# REQUEST_CAT  ZONING  ZONING/COMPLAINT/ INSPECT
# MERGE_INDEX
# 10_2016_10      4.0                        1.0
# 10_2016_100     1.0                        0.0
# 10_2016_101     0.0                        0.0
# 10_2016_102     0.0                        0.0
# 10_2016_103     0.0                        0.0
# 10_2016_105     0.0                        1.0
# 10_2016_106     0.0                        1.0
# 10_2016_107     0.0                        0.0
# 10_2016_108     0.0                        0.0
# 10_2016_109     1.0                        1.0
# 10_2016_11      3.0                        2.0
# 10_2016_110     3.0                        0.0
# 10_2016_111     0.0                        0.0
# 10_2016_112     0.0                        0.0
# 10_2016_113     0.0                        3.0
# 10_2016_114     0.0                        0.0
# 10_2016_115     0.0                        0.0
# 10_2016_116     1.0                        0.0
# 10_2016_117     0.0                        3.0
# 10_2016_118     0.0                        0.0
#
# [20 rows x 39 columns]

# %%
#check the min and max using describe
request_basket.describe()
# Out:
# REQUEST_CAT  311 DOCUMENT  ADMINISTRATIVE ACTIONS  ADOPT-A PICKUP SWS  \
# count        26271.000000            26271.000000        26271.000000
# mean             0.851852                0.088539            0.003883
# std              1.191478                0.366885            0.071847
# min              0.000000                0.000000            0.000000
# 25%              0.000000                0.000000            0.000000
# 50%              0.000000                0.000000            0.000000
# 75%              1.000000                0.000000            0.000000
# max             14.000000                8.000000            4.000000
#
# REQUEST_CAT  ANIMAL FOUND REPORT      BLOCKAGE  BOARDED UP STRUCTURE  \
# count               26271.000000  26271.000000          26271.000000
# mean                    0.045487      0.169845              0.008565
# std                     0.218714      0.464095              0.099690
# min                     0.000000      0.000000              0.000000
# 25%                     0.000000      0.000000              0.000000
# 50%                     0.000000      0.000000              0.000000
# 75%                     0.000000      0.000000              0.000000
# max                     4.000000      9.000000              3.000000
#
# REQUEST_CAT    BULKY ITEM          CART   CLEANLINESS     COMPLAINT  ...  \
# count        26271.000000  26271.000000  26271.000000  26271.000000  ...
# mean             0.306231      4.102280      0.131209      0.323018  ...
# std              0.670135      6.281683      0.409941      0.629465  ...
# min              0.000000      0.000000      0.000000      0.000000  ...
# 25%              0.000000      0.000000      0.000000      0.000000  ...
# 50%              0.000000      2.000000      0.000000      0.000000  ...
# 75%              0.000000      5.000000      0.000000      1.000000  ...
# max              9.000000    114.000000      6.000000      7.000000  ...
#
# REQUEST_CAT  SW ONLY-DOOR HANGER LEFT         TIRES  TRANSPORTATION  \
# count                    26271.000000  26271.000000    26271.000000
# mean                         0.014084      0.511591        1.997145
# std                          0.205444      0.978805        2.664610
# min                          0.000000      0.000000        0.000000
# 25%                          0.000000      0.000000        0.000000
# 50%                          0.000000      0.000000        1.000000
# 75%                          0.000000      1.000000        3.000000
# max                         15.000000     15.000000       49.000000
#
# REQUEST_CAT  UTILITY VERIFICATION LTR    VIOLATIONS  \
# count                    26271.000000  26271.000000
# mean                         0.054851      0.602223
# std                          0.269497      1.459714
# min                          0.000000      0.000000
# 25%                          0.000000      0.000000
# 50%                          0.000000      0.000000
# 75%                          0.000000      1.000000
# max                          6.000000     29.000000
#
# REQUEST_CAT  WEATHER AND ENVIRONMENTAL    YARD WASTE  \
# count                     26271.000000  26271.000000
# mean                          0.443112      0.601271
# std                           0.939404      1.241221
# min                           0.000000      0.000000
# 25%                           0.000000      0.000000
# 50%                           0.000000      0.000000
# 75%                           1.000000      1.000000
# max                          30.000000     30.000000
#
# REQUEST_CAT  ZON GENERAL INFO  INQUIRY        ZONING  \
# count                     26271.000000  26271.000000
# mean                          0.300483      0.434319
# std                           0.649909      0.842676
# min                           0.000000      0.000000
# 25%                           0.000000      0.000000
# 50%                           0.000000      0.000000
# 75%                           0.000000      1.000000
# max                           6.000000     15.000000
#
# REQUEST_CAT  ZONING/COMPLAINT/ INSPECT
# count                     26271.000000
# mean                          0.380419
# std                           0.987129
# min                           0.000000
# 25%                           0.000000
# 50%                           0.000000
# 75%                           0.000000
# max                          55.000000
#
# [8 rows x 39 columns]

# %%
request_basket.columns
# Out:
# Index(['311 DOCUMENT', 'ADMINISTRATIVE ACTIONS', 'ADOPT-A PICKUP SWS',
#        'ANIMAL FOUND REPORT', 'BLOCKAGE', 'BOARDED UP STRUCTURE', 'BULKY ITEM',
#        'CART', 'CLEANLINESS', 'COMPLAINT', 'CONTENT IMPROVEMENT PROG',
#        'CUSTOMER FEEDBACK', 'CWP', 'DEAD ANIMAL COLLECTION', 'DISABILITY ACT',
#        'DISABLED SERVICE', 'ESCALATION REQUEST', 'FIELD OBSERVED PROBLEM',
#        'GARBAGE', 'HNS HEALTH AND SANITATION', 'HNS HOUSING', 'MISSED SERVICE',
#        'NON_RECYCLABLE ITEMS', 'PARK & REC SVC REQUEST', 'RECYCLABLE ITEMS',
#        'RECYCLING', 'REQUEST FOR SPEAKER', 'STW CNTY WATER QUALITY',
#        'STW OTHER', 'SW ONLY-DOOR HANGER LEFT', 'TIRES', 'TRANSPORTATION',
#        'UTILITY VERIFICATION LTR', 'VIOLATIONS', 'WEATHER AND ENVIRONMENTAL',
#        'YARD WASTE', 'ZON GENERAL INFO  INQUIRY', 'ZONING',
#        'ZONING/COMPLAINT/ INSPECT'],
#       dtype='object', name='REQUEST_CAT')

# %%
#function to encode the value of a cell as 1 if it is >=1 and as 0 if it is <=0
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

    
#update the values in the request_basket_sets
request_basket_sets = request_basket.applymap(encode_units)

# %%
request_basket_sets.head(20)
# Out:
# REQUEST_CAT  311 DOCUMENT  ADMINISTRATIVE ACTIONS  ADOPT-A PICKUP SWS  \
# MERGE_INDEX
# 10_2016_10              1                       1                   0
# 10_2016_100             1                       0                   0
# 10_2016_101             0                       0                   0
# 10_2016_102             0                       0                   0
# 10_2016_103             1                       0                   0
# 10_2016_105             0                       1                   0
# 10_2016_106             0                       0                   0
# 10_2016_107             1                       0                   0
# 10_2016_108             0                       0                   0
# 10_2016_109             0                       0                   0
# 10_2016_11              1                       0                   0
# 10_2016_110             0                       0                   0
# 10_2016_111             0                       0                   0
# 10_2016_112             0                       0                   0
# 10_2016_113             1                       0                   0
# 10_2016_114             0                       1                   0
# 10_2016_115             0                       0                   0
# 10_2016_116             1                       1                   0
# 10_2016_117             1                       1                   0
# 10_2016_118             0                       0                   0
#
# REQUEST_CAT  ANIMAL FOUND REPORT  BLOCKAGE  BOARDED UP STRUCTURE  BULKY ITEM  \
# 10_2016_11                           0           0                          0
# 10_2016_110                          1           0                          0
# 10_2016_111                          1           0                          0
# 10_2016_112                          0           0                          0
# 10_2016_113                          0           0                          0
# 10_2016_114                          0           0                          0
# 10_2016_115                          1           0                          0
# 10_2016_116                          0           0                          0
# 10_2016_117                          1           0                          0
# 10_2016_118                          1           0                          0
#
# REQUEST_CAT  ZONING  ZONING/COMPLAINT/ INSPECT
# MERGE_INDEX
# 10_2016_10        1                          1
# 10_2016_100       1                          0
# 10_2016_101       0                          0
# 10_2016_102       0                          0
# 10_2016_103       0                          0
# 10_2016_105       0                          1
# 10_2016_106       0                          1
# 10_2016_107       0                          0
# 10_2016_108       0                          0
# 10_2016_109       1                          1
# 10_2016_11        1                          1
# 10_2016_110       1                          0
# 10_2016_111       0                          0
# 10_2016_112       0                          0
# 10_2016_113       0                          1
# 10_2016_114       0                          0
# 10_2016_115       0                          0
# 10_2016_116       1                          0
# 10_2016_117       0                          1
# 10_2016_118       0                          0
#
# [20 rows x 39 columns]

# %% [markdown]
# ### Association Rules concepts:
# "Support" is the relative frequency that the rules show up. In many instances, you may want to look for high support in order to make sure it is a useful relationship. However, there may be instances where a low support is useful if you are trying to find “hidden” relationships.
#
# "Confidence" is a measure of the reliability of the rule. A confidence of .5 in in an association rule X --> Y would mean that in 50% of the cases where X occurs, Y also occurs. Confidence that can be used as a threshold differs from industry to industry and case to case. For product recommendation, a 50% confidence may be perfectly acceptable but in a medical situation, this level may not be high enough.
#
# "Lift" is the ratio of the observed support to that expected if the two rules were independent. The basic rule of thumb is that a lift value close to 1 means the rules were completely independent. Lift values > 1 are generally more “interesting” and could be indicative of a useful rule pattern.
#
# <img src="https://wiki.smu.edu.sg/1718t3isss608/img_auth.php/thumb/b/b3/Lift_Confidence_Support.png/600px-Lift_Confidence_Support.png"/>

# %%
#get the frequent lists with min support of 0.4
frequent_itemsets = fpgrowth(request_basket_sets, min_support=0.4, use_colnames=True)
with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.max_colwidth', None):
    display(frequent_itemsets.sort_values(['support'],ascending=False))
# Out:
#      support  \
# 0   0.871988
# 1   0.811427
# 9   0.811046
# 2   0.714019
# 10  0.712801
# 11  0.692398
# 12  0.692284
# 3   0.650413
# 13  0.642990
# 4   0.625366
# 20  0.621217
# 14  0.619695
# 16  0.619619
# 24  0.601995
# 21  0.601995
# 15  0.565376
# 17  0.565110
# 18  0.554794
# 19  0.554794
# 22  0.548932
# 25  0.548704
# 26  0.539759
# 27  0.539759
# 5   0.521335
# 35  0.520117
# 23  0.503293
# 28  0.502227
# 6   0.500818
# 46  0.500095
# 36  0.499296
# 39  0.499258
# 31  0.492596
# 29  0.492596
# 47  0.488143
# 51  0.488105
# 7   0.487458
# 30  0.457691
# 32  0.457539
# 48  0.456587
# 52  0.456359
# 37  0.456206
# 40  0.455826
# 33  0.452400
# 34  0.452400
# 54  0.449469
# 53  0.449469
# 41  0.446348
# 42  0.446348
# 59  0.418865
# 38  0.411861
# 43  0.411556
# 49  0.407522
# 55  0.407293
# 60  0.406342
# 61  0.406227
# 8   0.404134
# 62  0.403867
# 44  0.401926
# 45  0.401888
# 56  0.401203
# 57  0.401165
# 50  0.400137
# 58  0.400023
#
#                                                                                      itemsets
# 0                                                                      (NON_RECYCLABLE ITEMS)
# 1                                                                          (RECYCLABLE ITEMS)
# 9                                                    (NON_RECYCLABLE ITEMS, RECYCLABLE ITEMS)
# 2                                                                                      (CART)
# 10                                                               (CART, NON_RECYCLABLE ITEMS)
# 11                                                                   (CART, RECYCLABLE ITEMS)
# 12                                             (CART, NON_RECYCLABLE ITEMS, RECYCLABLE ITEMS)
# 3                                                                            (TRANSPORTATION)
# 13                                                     (TRANSPORTATION, NON_RECYCLABLE ITEMS)
# 4                                                                 (HNS HEALTH AND SANITATION)
# 20                                          (HNS HEALTH AND SANITATION, NON_RECYCLABLE ITEMS)
# 14                                                         (TRANSPORTATION, RECYCLABLE ITEMS)
# 16                                   (TRANSPORTATION, NON_RECYCLABLE ITEMS, RECYCLABLE ITEMS)
# 24                        (HNS HEALTH AND SANITATION, NON_RECYCLABLE ITEMS, RECYCLABLE ITEMS)
# 21                                              (HNS HEALTH AND SANITATION, RECYCLABLE ITEMS)
# 15                                                                     (TRANSPORTATION, CART)
# 17                                               (NON_RECYCLABLE ITEMS, TRANSPORTATION, CART)
# 18                                                   (TRANSPORTATION, CART, RECYCLABLE ITEMS)
# 19                             (NON_RECYCLABLE ITEMS, TRANSPORTATION, CART, RECYCLABLE ITEMS)
# 22                                                          (HNS HEALTH AND SANITATION, CART)
# 25                                    (HNS HEALTH AND SANITATION, CART, NON_RECYCLABLE ITEMS)
# 26                                        (HNS HEALTH AND SANITATION, CART, RECYCLABLE ITEMS)
# 27                  (HNS HEALTH AND SANITATION, CART, NON_RECYCLABLE ITEMS, RECYCLABLE ITEMS)
# 5                                                                            (MISSED SERVICE)
# 35                                                     (MISSED SERVICE, NON_RECYCLABLE ITEMS)
# 23                                                (TRANSPORTATION, HNS HEALTH AND SANITATION)
# 28                          (TRANSPORTATION, HNS HEALTH AND SANITATION, NON_RECYCLABLE ITEMS)
# 6                                                                                   (GARBAGE)
# 46                                                            (GARBAGE, NON_RECYCLABLE ITEMS)
# 36                                                         (MISSED SERVICE, RECYCLABLE ITEMS)
# 39                                   (MISSED SERVICE, NON_RECYCLABLE ITEMS, RECYCLABLE ITEMS)
# 31        (TRANSPORTATION, HNS HEALTH AND SANITATION, NON_RECYCLABLE ITEMS, RECYCLABLE ITEMS)
# 29                              (TRANSPORTATION, HNS HEALTH AND SANITATION, RECYCLABLE ITEMS)
# 47                                                                (GARBAGE, RECYCLABLE ITEMS)
# 51                                          (GARBAGE, NON_RECYCLABLE ITEMS, RECYCLABLE ITEMS)
# 7                                                                              (311 DOCUMENT)
# 30                                          (TRANSPORTATION, HNS HEALTH AND SANITATION, CART)
# 32                    (NON_RECYCLABLE ITEMS, TRANSPORTATION, HNS HEALTH AND SANITATION, CART)
# 48                                                                            (GARBAGE, CART)
# 52                                                      (GARBAGE, CART, NON_RECYCLABLE ITEMS)
# 37                                                                     (MISSED SERVICE, CART)
# 40                                               (MISSED SERVICE, CART, NON_RECYCLABLE ITEMS)
# 33                        (TRANSPORTATION, HNS HEALTH AND SANITATION, CART, RECYCLABLE ITEMS)
# 34  (TRANSPORTATION, CART, HNS HEALTH AND SANITATION, NON_RECYCLABLE ITEMS, RECYCLABLE ITEMS)
# 54                                    (GARBAGE, CART, NON_RECYCLABLE ITEMS, RECYCLABLE ITEMS)
# 53                                                          (GARBAGE, CART, RECYCLABLE ITEMS)
# 41                                                   (MISSED SERVICE, CART, RECYCLABLE ITEMS)
# 42                             (MISSED SERVICE, CART, NON_RECYCLABLE ITEMS, RECYCLABLE ITEMS)
# 59                                                       (311 DOCUMENT, NON_RECYCLABLE ITEMS)
# 38                                                           (TRANSPORTATION, MISSED SERVICE)
# 43                                     (TRANSPORTATION, MISSED SERVICE, NON_RECYCLABLE ITEMS)
# 49                                                                  (GARBAGE, TRANSPORTATION)
# 55                                            (GARBAGE, TRANSPORTATION, NON_RECYCLABLE ITEMS)
# 60                                                           (311 DOCUMENT, RECYCLABLE ITEMS)
# 61                                     (311 DOCUMENT, NON_RECYCLABLE ITEMS, RECYCLABLE ITEMS)
# 8                                                                                 (RECYCLING)
# 62                                                          (RECYCLING, NON_RECYCLABLE ITEMS)
# 44                                         (TRANSPORTATION, MISSED SERVICE, RECYCLABLE ITEMS)
# 45                   (TRANSPORTATION, MISSED SERVICE, NON_RECYCLABLE ITEMS, RECYCLABLE ITEMS)
# 56                                                (GARBAGE, TRANSPORTATION, RECYCLABLE ITEMS)
# 57                          (GARBAGE, TRANSPORTATION, NON_RECYCLABLE ITEMS, RECYCLABLE ITEMS)
# 50                                                       (GARBAGE, HNS HEALTH AND SANITATION)
# 58                                 (GARBAGE, HNS HEALTH AND SANITATION, NON_RECYCLABLE ITEMS)

# %% [markdown]
# ### Inference:
#
# We can see that the support of NON_RECYCLABLE ITEMS and RECYCLABLE ITEMS is the highest in the frequest item sets which aligns with our data because these two are the highest reported type of 311 service requests.
#
# The next highest are CART, TRANSPORTATION, HNS HEALTH AND SANITATION, MISSED SERVICE, GARBAGE and RECYCLING. All these are likely to occur in the same neighborhood profile area along with NON_RECYCLABLE ITEMS and RECYCLABLE ITEMS within a time-span of a month.
#
# We also see a few instances of 311 DOCUMENT which is likely to occur with NON_RECYCLABLE ITEMS and RECYCLABLE ITEMS

# %%
#creating the frequest request sets. We use a minimum support of 0.1 to create 
# more number of frequent lists than seen above
frequent_reqsets = apriori(request_basket_sets, min_support=0.1, use_colnames=True)

# %%
#generate rules with a minimum threshold as 1
rules = association_rules(frequent_reqsets, metric="lift", min_threshold=1)
rules.head(30)
# Out:
#                     antecedents                  consequents  \
# 0                (311 DOCUMENT)                 (BULKY ITEM)
# 1                  (BULKY ITEM)               (311 DOCUMENT)
# 2                (311 DOCUMENT)                       (CART)
# 3                        (CART)               (311 DOCUMENT)
# 4                (311 DOCUMENT)                  (COMPLAINT)
# 5                   (COMPLAINT)               (311 DOCUMENT)
# 6           (CUSTOMER FEEDBACK)               (311 DOCUMENT)
# 7                (311 DOCUMENT)          (CUSTOMER FEEDBACK)
# 8                (311 DOCUMENT)     (DEAD ANIMAL COLLECTION)
# 9      (DEAD ANIMAL COLLECTION)               (311 DOCUMENT)
# 10                    (GARBAGE)               (311 DOCUMENT)
# 11               (311 DOCUMENT)                    (GARBAGE)
# 12               (311 DOCUMENT)  (HNS HEALTH AND SANITATION)
# 13  (HNS HEALTH AND SANITATION)               (311 DOCUMENT)
# 14                (HNS HOUSING)               (311 DOCUMENT)
# 15               (311 DOCUMENT)                (HNS HOUSING)
# 16               (311 DOCUMENT)             (MISSED SERVICE)
# 17             (MISSED SERVICE)               (311 DOCUMENT)
# 18               (311 DOCUMENT)           (RECYCLABLE ITEMS)
# 19           (RECYCLABLE ITEMS)               (311 DOCUMENT)
# 20               (311 DOCUMENT)                  (RECYCLING)
# 21                  (RECYCLING)               (311 DOCUMENT)
# 22                      (TIRES)               (311 DOCUMENT)
# 23               (311 DOCUMENT)                      (TIRES)
# 24             (TRANSPORTATION)               (311 DOCUMENT)
# 25               (311 DOCUMENT)             (TRANSPORTATION)
# 26                 (VIOLATIONS)               (311 DOCUMENT)
# 27               (311 DOCUMENT)                 (VIOLATIONS)
# 28               (311 DOCUMENT)  (WEATHER AND ENVIRONMENTAL)
# 29  (WEATHER AND ENVIRONMENTAL)               (311 DOCUMENT)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0
# 116975                 (TRANSPORTATION, RECYCLABLE ITEMS)
# 116976                          (GARBAGE, MISSED SERVICE)
# 116977                                    (GARBAGE, CART)
# 116978               (GARBAGE, HNS HEALTH AND SANITATION)
# 116979                    (GARBAGE, NON_RECYCLABLE ITEMS)
# 116980                        (GARBAGE, RECYCLABLE ITEMS)
# 116981                             (MISSED SERVICE, CART)
# 116982        (HNS HEALTH AND SANITATION, MISSED SERVICE)
# 116983             (MISSED SERVICE, NON_RECYCLABLE ITEMS)
# 116984                 (MISSED SERVICE, RECYCLABLE ITEMS)
# 116985                  (HNS HEALTH AND SANITATION, CART)
# 116986                       (NON_RECYCLABLE ITEMS, CART)
# 116987                           (CART, RECYCLABLE ITEMS)
# 116988  (HNS HEALTH AND SANITATION, NON_RECYCLABLE ITEMS)
# 116989      (HNS HEALTH AND SANITATION, RECYCLABLE ITEMS)
# 116990           (NON_RECYCLABLE ITEMS, RECYCLABLE ITEMS)
# 116991                                     (311 DOCUMENT)
# 116992                                        (RECYCLING)
# 116993                                   (TRANSPORTATION)
# 116994                                          (GARBAGE)
# 116995                                   (MISSED SERVICE)
# 116996                                             (CART)
# 116997                        (HNS HEALTH AND SANITATION)
# 116998                             (NON_RECYCLABLE ITEMS)
# 116999                                 (RECYCLABLE ITEMS)
#
#                                               consequents  antecedent support  \
# 116970  (311 DOCUMENT, RECYCLING, MISSED SERVICE, CART...            0.407522
# 116971  (311 DOCUMENT, RECYCLING, GARBAGE, CART, HNS H...            0.411861
# 116972  (311 DOCUMENT, RECYCLING, GARBAGE, MISSED SERV...            0.565376
# 116973  (311 DOCUMENT, RECYCLING, GARBAGE, MISSED SERV...            0.503293
# 116974  (311 DOCUMENT, RECYCLING, GARBAGE, MISSED SERV...            0.642990
# 116975  (311 DOCUMENT, RECYCLING, GARBAGE, MISSED SERV...            0.619695
# 116976  (TRANSPORTATION, 311 DOCUMENT, RECYCLING, CART...            0.341593
# 116977  (TRANSPORTATION, 311 DOCUMENT, RECYCLING, MISS...            0.456587
# 116978  (TRANSPORTATION, 311 DOCUMENT, RECYCLING, MISS...            0.400137
# 116979  (TRANSPORTATION, 311 DOCUMENT, RECYCLING, MISS...            0.500095
# 116980  (TRANSPORTATION, 311 DOCUMENT, RECYCLING, MISS...            0.488143
# 116981  (TRANSPORTATION, 311 DOCUMENT, RECYCLING, GARB...            0.456206
# 116982  (TRANSPORTATION, 311 DOCUMENT, RECYCLING, GARB...            0.397587
# 116983  (TRANSPORTATION, 311 DOCUMENT, RECYCLING, GARB...            0.520117
# 116984  (TRANSPORTATION, 311 DOCUMENT, RECYCLING, GARB...            0.499296
# 116985  (TRANSPORTATION, 311 DOCUMENT, RECYCLING, GARB...            0.548932
# 116986  (TRANSPORTATION, 311 DOCUMENT, RECYCLING, GARB...            0.712801
# 116987  (TRANSPORTATION, 311 DOCUMENT, RECYCLING, GARB...            0.692398
# 116988  (TRANSPORTATION, 311 DOCUMENT, RECYCLING, GARB...            0.621217
# 116989  (TRANSPORTATION, 311 DOCUMENT, RECYCLING, GARB...            0.601995
# 116990  (TRANSPORTATION, 311 DOCUMENT, RECYCLING, GARB...            0.811046
# 116996    1.046889
# 116997    1.059349
# 116998    1.017399
# 116999    1.027476

# %%
rules.describe()
# Out:
#        antecedent support  consequent support        support     confidence  \
# count       117000.000000       117000.000000  117000.000000  117000.000000
# mean             0.337491            0.337491       0.134623       0.508276
# std              0.188173            0.188173       0.043766       0.247092
# min              0.100148            0.100148       0.100148       0.114851
# 25%              0.187736            0.187736       0.107761       0.301984
# 50%              0.280347            0.280347       0.119790       0.461246
# 75%              0.455826            0.455826       0.144304       0.697055
# max              0.871988            0.871988       0.811046       1.000000
#
#                 lift       leverage    conviction
# count  117000.000000  117000.000000  1.170000e+05
# mean        1.543043       0.044619           inf
# std         0.189798       0.012621           NaN
# min         1.027318       0.007630  1.010300e+00
# 25%         1.403026       0.037624  1.155712e+00
# 50%         1.549216       0.044262  1.330334e+00
# 75%         1.675661       0.051133  1.845136e+00
# max         2.121184       0.113898           inf

# %% [markdown]
# ### Inference:
# We see that the highest lift is 2.12 and we also have some perfect confidence scores of 1.
#
# To select the most frequent association rules, we choose a high lift (>2) and a high confidence too (>0.65 which is close to the 75% mark)

# %%
#fetch the most reliable association rules
with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.max_colwidth', None):
    display(rules[ (rules['lift'] >= 2) &
        (rules['confidence'] >= 0.65)].sort_values(['lift'],ascending=False) )
# Out:
#                                                                                        antecedents  \
# 98862                                           (HNS HEALTH AND SANITATION, RECYCLING, YARD WASTE)
# 113607                                          (HNS HEALTH AND SANITATION, RECYCLING, YARD WASTE)
# 113546                    (NON_RECYCLABLE ITEMS, HNS HEALTH AND SANITATION, RECYCLING, YARD WASTE)
# 113547                        (HNS HEALTH AND SANITATION, RECYCLING, YARD WASTE, RECYCLABLE ITEMS)
# 113497  (RECYCLING, YARD WASTE, HNS HEALTH AND SANITATION, NON_RECYCLABLE ITEMS, RECYCLABLE ITEMS)
# 98833                         (HNS HEALTH AND SANITATION, RECYCLING, YARD WASTE, RECYCLABLE ITEMS)
# 97980                                           (HNS HEALTH AND SANITATION, RECYCLING, YARD WASTE)
# 66192                                           (HNS HEALTH AND SANITATION, RECYCLING, YARD WASTE)
# 97951                     (NON_RECYCLABLE ITEMS, HNS HEALTH AND SANITATION, RECYCLING, YARD WASTE)
# 115406                                               (VIOLATIONS, RECYCLING, NON_RECYCLABLE ITEMS)
# 101798                                                                     (VIOLATIONS, RECYCLING)
# 115445                                                                     (VIOLATIONS, RECYCLING)
# 101775                                                   (VIOLATIONS, RECYCLING, RECYCLABLE ITEMS)
# 115407                                                   (VIOLATIONS, RECYCLING, RECYCLABLE ITEMS)
# 115356                             (VIOLATIONS, RECYCLING, NON_RECYCLABLE ITEMS, RECYCLABLE ITEMS)
# 101397                                               (VIOLATIONS, RECYCLING, NON_RECYCLABLE ITEMS)
# 68818                                                                      (VIOLATIONS, RECYCLING)
# 101420                                                                     (VIOLATIONS, RECYCLING)
# 115352                                         (NON_RECYCLABLE ITEMS, VIOLATIONS, RECYCLING, CART)
# 115404                                                               (VIOLATIONS, RECYCLING, CART)
# 101773                                                               (VIOLATIONS, RECYCLING, CART)
# 115353                                             (VIOLATIONS, RECYCLING, CART, RECYCLABLE ITEMS)
# 101746                                             (VIOLATIONS, RECYCLING, CART, RECYCLABLE ITEMS)
# 115299                       (RECYCLING, VIOLATIONS, CART, NON_RECYCLABLE ITEMS, RECYCLABLE ITEMS)
# 101368                                         (NON_RECYCLABLE ITEMS, VIOLATIONS, RECYCLING, CART)
# 101395                                                               (VIOLATIONS, RECYCLING, CART)
# 68804                                                                (VIOLATIONS, RECYCLING, CART)
# 115857                                      (GARBAGE, RECYCLING, NON_RECYCLABLE ITEMS, YARD WASTE)
# 103284                                                            (GARBAGE, RECYCLING, YARD WASTE)
# 115911                                                            (GARBAGE, RECYCLING, YARD WASTE)
#
#                                                                                                consequents  \
# 98862                                                    (GARBAGE, MISSED SERVICE, CART, RECYCLABLE ITEMS)
# 113607                             (GARBAGE, MISSED SERVICE, CART, NON_RECYCLABLE ITEMS, RECYCLABLE ITEMS)
# 113546                                                   (GARBAGE, MISSED SERVICE, CART, RECYCLABLE ITEMS)
# 113547                                               (GARBAGE, MISSED SERVICE, NON_RECYCLABLE ITEMS, CART)
# 113497                                                                     (GARBAGE, MISSED SERVICE, CART)
# 98833                                                                      (GARBAGE, MISSED SERVICE, CART)
# 97980                                                (GARBAGE, MISSED SERVICE, NON_RECYCLABLE ITEMS, CART)
# 66192                                                                      (GARBAGE, MISSED SERVICE, CART)
# 97951                                                                      (GARBAGE, MISSED SERVICE, CART)
# 115406                        (TRANSPORTATION, GARBAGE, CART, HNS HEALTH AND SANITATION, RECYCLABLE ITEMS)
# 101798                        (TRANSPORTATION, GARBAGE, CART, HNS HEALTH AND SANITATION, RECYCLABLE ITEMS)
# 115445  (TRANSPORTATION, GARBAGE, CART, HNS HEALTH AND SANITATION, NON_RECYCLABLE ITEMS, RECYCLABLE ITEMS)
# 101775                                          (GARBAGE, TRANSPORTATION, HNS HEALTH AND SANITATION, CART)
# 115407                    (TRANSPORTATION, GARBAGE, CART, HNS HEALTH AND SANITATION, NON_RECYCLABLE ITEMS)
# 115356                                          (GARBAGE, TRANSPORTATION, HNS HEALTH AND SANITATION, CART)
# 101397                                          (GARBAGE, TRANSPORTATION, HNS HEALTH AND SANITATION, CART)
# 68818                                           (GARBAGE, TRANSPORTATION, HNS HEALTH AND SANITATION, CART)
# 101420                    (TRANSPORTATION, GARBAGE, CART, HNS HEALTH AND SANITATION, NON_RECYCLABLE ITEMS)
# 115352                              (GARBAGE, TRANSPORTATION, HNS HEALTH AND SANITATION, RECYCLABLE ITEMS)
# 115404        (TRANSPORTATION, GARBAGE, HNS HEALTH AND SANITATION, NON_RECYCLABLE ITEMS, RECYCLABLE ITEMS)
# 101773                              (GARBAGE, TRANSPORTATION, HNS HEALTH AND SANITATION, RECYCLABLE ITEMS)
# 115353                          (GARBAGE, TRANSPORTATION, HNS HEALTH AND SANITATION, NON_RECYCLABLE ITEMS)
# 101746                                                (GARBAGE, TRANSPORTATION, HNS HEALTH AND SANITATION)
# 115299                                                (GARBAGE, TRANSPORTATION, HNS HEALTH AND SANITATION)
# 101368                                                (GARBAGE, TRANSPORTATION, HNS HEALTH AND SANITATION)
# 101395                          (GARBAGE, TRANSPORTATION, HNS HEALTH AND SANITATION, NON_RECYCLABLE ITEMS)
# 68804                                                 (GARBAGE, TRANSPORTATION, HNS HEALTH AND SANITATION)
# 115857                                            (TRANSPORTATION, MISSED SERVICE, CART, RECYCLABLE ITEMS)
# 103284                                            (TRANSPORTATION, MISSED SERVICE, CART, RECYCLABLE ITEMS)
